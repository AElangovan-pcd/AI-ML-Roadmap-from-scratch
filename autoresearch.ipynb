# %% [markdown]
# <a href="https://colab.research.google.com/github/AElangovan-pcd/AI-ML-Roadmap-from-scratch/blob/main/autoresearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check GPU
# !nvidia-smi
# Install uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Clone and setup
# !git clone https://github.com/karpathy/autoresearch.git
# %cd autoresearch
# !uv sync
# Train with reduced batch size to fit 40GB A100
# !sed -i 's/DEVICE_BATCH_SIZE = 128/DEVICE_BATCH_SIZE = 64/' train.py
# !uv run train.py
# Prepare data
# !uv run prepare.py

# Train
# !uv run train.py
# Out:
# Sun Apr 12 22:15:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...
